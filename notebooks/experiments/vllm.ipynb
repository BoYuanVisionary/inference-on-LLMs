# %% [markdown]
# vllm has a long existing issue on memory leakage. It seems to be unreliable on multiple GPUs.

# %% [markdown]
# Can I run vllm only with cpu? Seems no currently

# %% [markdown]
# vllm does not support deployment on multiple gpus with os.environ["cuda_visible_devices"]
#
# UPDATE: the previous comment is wrong. It does support multiple GPUs. Be careful with the name of the environment variable.
# os.environ["CUDA_VISIBLE_DEVICES"]

# %% [markdown]
# For some models, it does not support odd number of GPUs.

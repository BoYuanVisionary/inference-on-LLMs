# %%
# load the libraies dynamcally so that no need to restart

from reasoning.MCTS.mcts import MCTS
from reasoning.models.model import Model
from reasoning.MCTS.task import MCTS_Task
from reasoning.tools.utils import seed_everything
seed_everything(110)

# %%
model_class = Model('meta-llama/Llama-3.2-3B-Instruct')
question = "Calculate the result of 3 + 4 * 5."
answer = '\\boxed{23}'
task = MCTS_Task(question, answer = answer, propose_method=model_class, value_method=model_class,iteration_limit=10)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
output = task.run()
# Out:
# <beging new round, current round:0>
#
# ----------------------------------------
# selection phase
#
# selected node:
# ----------------------------------------
# expansion phase
#
#
#  ============================== proposal ==============================
# step:  1
# standardized next step: Step 1: Identify the mathematical operation that needs to be performed first according to the order of operations (PEMDAS/BODMAS). According to the order of operations, multiplication comes before addition. Therefore, the first step is to perform the multiplication operation between 4 and 5.  ##
#
#
#  ============================== proposal ==============================
# step:  1
# standardized next step: Step 1: Understand the order of operations The problem requires us to calculate the result of 3 + 4 * 5, following the order of operations (PEMDAS/BODMAS). The order of operations states that we should perform multiplication before addition.   ##
#
#
# ...
